# %%
import pandas as pd
import numpy as np
import re
import ast

from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans



path = "../raw_data/goodreads_books_50k.csv"
df = pd.read_csv(path)

print("shape：", df.shape)
df.head()
# Out:
# shape： (50000, 29)
#          isbn  text_reviews_count      series country_code language_code  \
# 0  0312853122                 1.0          []           US           NaN
# 1  0743509986                 6.0          []           US           NaN
# 2         NaN                 7.0  ['189911']           US           eng
# 3  0743294297              3282.0          []           US           eng
# 4  0850308712                 5.0          []           US           NaN
#
#                                      popular_shelves        asin is_ebook  \
# 0  [{'count': '3', 'name': 'to-read'}, {'count': ...         NaN    False
# 1  [{'count': '2634', 'name': 'to-read'}, {'count...         NaN    False
# 2  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY    False
# 3  [{'count': '7615', 'name': 'to-read'}, {'count...         NaN    False
# 4  [{'count': '32', 'name': 'to-read'}, {'count':...         NaN    False
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.00         NaN  ...               9.0                 NaN
# 1            3.23  B000FC0PBC  ...              10.0            Abridged
# 2            4.03         NaN  ...               NaN   Book Club Edition
# 3            3.49  B002ENBLOK  ...               7.0                 NaN
# 4            3.40         NaN  ...               NaN                 NaN
#
#   publication_year                                                url  \
# 0           1984.0  https://www.goodreads.com/book/show/5333265-w-...
# 1           2001.0  https://www.goodreads.com/book/show/1333909.Go...
# 2           1987.0  https://www.goodreads.com/book/show/7327624-th...
# 3           2009.0  https://www.goodreads.com/book/show/6066819-be...
# 4              NaN  https://www.goodreads.com/book/show/287140.Run...
#
#                                            image_url  book_id  ratings_count  \
# 0  https://images.gr-assets.com/books/1310220028m...  5333265            3.0
# 1  https://s.gr-assets.com/assets/nophoto/book/11...  1333909           10.0
# 2  https://images.gr-assets.com/books/1304100136m...  7327624          140.0
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  6066819        51184.0
# 4  https://images.gr-assets.com/books/1413219371m...   287140           15.0
#
#      work_id                                              title  \
# 0  5400751.0                        W.C. Fields: A Life on Film
# 1  1323437.0                                        Good Harbor
# 2  8948723.0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3  6243154.0                               Best Friends Forever
# 4   278577.0  Runic Astrology: Starcraft and Timekeeping in ...
#
#                                 title_without_series
# 0                        W.C. Fields: A Life on Film
# 1                                        Good Harbor
# 2  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3                               Best Friends Forever
# 4  Runic Astrology: Starcraft and Timekeeping in ...
#
# [5 rows x 29 columns]

# %%
english_codes = ["eng", "en-US", "en-GB", "en-CA","NaN"]
df = df[df["language_code"].isin(english_codes)].copy()

# %%
df = df.dropna(subset=["title", "description"], how="all").reset_index(drop=True)
#drop rows where both title and description are NaN

# %%
df.shape
# Out:
# (18621, 29)

# %%
cols_to_drop = [
    "edition_information",
    "asin",
    "kindle_asin",
    "publication_day",
    "publication_month",
    "format",
    "publisher",
    "isbn"
]

df = df.drop(columns=cols_to_drop, errors="ignore")

# %%
df.shape
# Out:
# (18621, 21)

# %%
for col in ["average_rating", "ratings_count", "text_reviews_count"]:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

df[["average_rating", "ratings_count", "text_reviews_count"]].describe()
# Out:
#        average_rating  ratings_count  text_reviews_count
# count    18621.000000   18621.000000        18621.000000
# mean         3.923501     867.937866           61.632028
# std          0.473281    9684.768052          556.502131
# min          0.000000       0.000000            0.000000
# 25%          3.700000       9.000000            2.000000
# 50%          3.950000      38.000000            7.000000
# 75%          4.190000     174.000000           23.000000
# max          5.000000  575163.000000        38878.000000

# %%
def clean_text(s):
    if not isinstance(s, str):
        return ""
    s = s.lower()
    s = re.sub(r"<.*?>", " ", s)                    # remove HTML tags
    s = s.replace("\n", " ").replace("\r", " ").replace("\t", " ")
    s = re.sub(r"\s+", " ", s).strip()
    return s

# %%
df["title_clean"] = (
    df["title_without_series"]
    .fillna(df["title"])
    .fillna("")
    .astype(str)
    .str.lower()
)

# %%
df["description_clean"] = df["description"].fillna("").astype(str).apply(clean_text)

df[["title_clean", "description_clean"]].head()
# Out:
#                                          title_clean  \
# 0  the unschooled wizard (sun wolf and starhawk, ...
# 1                               best friends forever
# 2            the house of memory (pluto's snitch #2)
# 3                        the bonfire of the vanities
# 4                                             heaven
#
#                                    description_clean
# 0  omnibus book club edition containing the ladie...
# 1  addie downs and valerie adler were eight when ...
# 2
# 3
# 4  what is heaven really going to be like? what w...

# %%
def parse_shelves(s):
    try:
        lst = ast.literal_eval(s)
        return [d.get("name") for d in lst if isinstance(d, dict)]
    except:
        return []

df["shelf_names"] = df["popular_shelves"].apply(parse_shelves)

# %%
def parse_authors(s):
    try:
        lst = ast.literal_eval(s)
        return [d.get("author_id") for d in lst if isinstance(d, dict)]
    except:
        return []

df["author_ids"] = df["authors"].apply(parse_authors)

# %%
def parse_similar(s):
    try:
        return ast.literal_eval(s)
    except:
        return []

df["similar_books_list"] = df["similar_books"].apply(parse_similar)

df[["shelf_names", "author_ids", "similar_books_list"]].head()
# Out:
#                                          shelf_names author_ids  \
# 0  [to-read, fantasy, fiction, owned, hardcover, ...    [10333]
# 1  [to-read, chick-lit, currently-reading, fictio...     [9212]
# 2  [currently-reading, netgalley, kindle, read-20...   [242185]
# 3  [to-read, fiction, favorites, classics, curren...  [3083854]
# 4  [to-read, currently-reading, theology, christi...     [4862]
#
#                                   similar_books_list
# 0  [19997, 828466, 1569323, 425389, 1176674, 2627...
# 1  [6604176, 6054190, 2285777, 82641, 7569453, 70...
# 2                                                 []
# 3  [415854, 45794, 871284, 12881, 11662, 261444, ...
# 4  [45366, 246849, 11096385, 19102466, 761197, 11...

# %%
# shelves → "fantasy magic young-adult"
df["shelf_text"] = df["shelf_names"].apply(
    lambda lst: " ".join(lst) if isinstance(lst, list) else ""
)

# %%
df["author_text"] = df["author_ids"].apply(
    lambda lst: " ".join("author_" + str(a) for a in lst) if isinstance(lst, list) else ""
)

# %%
# similar_books → "sim_111 sim_222 sim_333"
df["sim_text"] = df["similar_books_list"].apply(
    lambda lst: " ".join("sim_" + str(b) for b in lst) if isinstance(lst, list) else ""
)

df[["shelf_text", "author_text", "sim_text"]].head()
# Out:
#                                           shelf_text     author_text  \
# 0  to-read fantasy fiction owned hardcover shelfa...    author_10333
# 1  to-read chick-lit currently-reading fiction bo...     author_9212
# 2  currently-reading netgalley kindle read-2017 r...   author_242185
# 3  to-read fiction favorites classics currently-r...  author_3083854
# 4  to-read currently-reading theology christian-l...     author_4862
#
#                                             sim_text
# 0  sim_19997 sim_828466 sim_1569323 sim_425389 si...
# 1  sim_6604176 sim_6054190 sim_2285777 sim_82641 ...
# 2
# 3  sim_415854 sim_45794 sim_871284 sim_12881 sim_...
# 4  sim_45366 sim_246849 sim_11096385 sim_19102466...

# %%
df["combined_text"] = (
    df["title_clean"].fillna("") + " " +
    df["description_clean"].fillna("") + " " +
    df["shelf_text"].fillna("") + " " +
    df["author_text"].fillna("") + " " +
    df["sim_text"].fillna("")
).str.strip()

df["combined_text"].head()
# Out:
# 0    the unschooled wizard (sun wolf and starhawk, ...
# 1    best friends forever addie downs and valerie a...
# 2    the house of memory (pluto's snitch #2)  curre...
# 3    the bonfire of the vanities  to-read fiction f...
# 4    heaven what is heaven really going to be like?...
# Name: combined_text, dtype: object

# %%
vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=30000,
    min_df=5,
    max_df=0.8
)

# %%
tfidf_matrix = vectorizer.fit_transform(df["combined_text"])

tfidf_matrix.shape
# Out:
# (18621, 29526)

# %% [markdown]
# many information is missing in "edition_information", also not helpful, "asin" (Amazon ID, can delete), "kindle_asin" (Kindle Amazin ID), "publication_day", "publication_month", "format", "publisher", "isbn". Could be removed.

# %%
from sklearn.cluster import MiniBatchKMeans

n_clusters = 30  # 更细分类

kmeans = MiniBatchKMeans(
    n_clusters=n_clusters,
    random_state=42,
    batch_size=2000
)

cluster_labels = kmeans.fit_predict(tfidf_matrix)

df["cluster"] = cluster_labels

df["cluster"].value_counts().sort_index()
# Out:
# cluster
# 0       45
# 1      907
# 2     1055
# 3      451
# 4      780
# 5      151
# 6      189
# 7      589
# 8        2
# 9      362
# 10     839
# 11     420
# 12     215
# 13      62
# 14    5173
# 15     266
# 16     426
# 17     179
# 18     958
# 19     606
# 20     466
# 21     680
# 22      68
# 23     278
# 24     231
# 25     556
# 26     824
# 27    1277
# 28      84
# 29     482
# Name: count, dtype: int64

# %%
def show_cluster(c, n=15):
    subset = df[df["cluster"] == c]
    return subset[["title", "average_rating", "ratings_count"]].head(n)

# %%
show_cluster(0)
# Out:
#                                                   title  average_rating  \
# 215                               Doctor Who: The Child            3.14
# 1359                          Torchwood: In the Shadows            3.98
# 1474                 Doctor Who: Short Trips - Volume 1            3.59
# 2020                             Torchwood: Exodus Code            3.87
# 2279  Torchwood: Corpse Day (Big Finish Torchwood, #...            3.82
# 2311                The Case of The Disappearing Doctor            3.17
# 2673                            Doctor Who: Scaredy Cat            2.62
# 4126                               Doctor Who: Survival            3.58
# 4572                           Doctor Who: The Forsaken            3.83
# 4684                 The Tunnel At The End Of The Light            2.83
# 5367  Professor Bernice Summerfield and The Greatest...            3.24
# 5647  Doctor Who: The Tenth Doctor Adventures, Volume 1            4.41
# 7215                    Doctor Who: Big Bang Generation            3.19
# 7371                        Doctor Who And The Cybermen            3.57
# 7372                               Doctor Who: Cybermen            3.94
#
#       ratings_count
# 215            29.0
# 1359          211.0
# 1474           68.0
# 2020           96.0
# 2279           38.0
# 2311           12.0
# 2673          144.0
# 4126           89.0
# 4572           36.0
# 4684           20.0
# 5367           34.0
# 5647           51.0
# 7215            4.0
# 7371           28.0
# 7372           68.0

# %%
from collections import Counter

def cluster_top_shelves(cluster_id, top_n=10):
    shelves_series = df[df["cluster"] == cluster_id]["shelf_names"]
    flat = [s for lst in shelves_series for s in lst]  # 展开所有标签
    c = Counter(flat)
    return c.most_common(top_n)

# %%
cluster_top_shelves(0, top_n=10)
# Out:
# [('to-read', 45),
#  ('doctor-who', 41),
#  ('science-fiction', 37),
#  ('sci-fi', 37),
#  ('owned', 33),
#  ('fiction', 32),
#  ('audiobooks', 30),
#  ('dr-who', 30),
#  ('audio', 28),
#  ('favorites', 25)]

# %%
import numpy as np

terms = vectorizer.get_feature_names_out()
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

def cluster_keywords(cluster_id, top_n=10):
    return [terms[i] for i in order_centroids[cluster_id, :top_n]]

# 示例：
cluster_keywords(0, top_n=10)
# Out:
# ['doctor',
#  'tv',
#  'dw',
#  'dr',
#  'audio',
#  'big',
#  'audios',
#  'fiction',
#  'tie',
#  'torchwood']

# %%
def auto_cluster_label(cluster_id):
    top_shelves = [s for s, _ in cluster_top_shelves(cluster_id, top_n=5)]
    top_words = cluster_keywords(cluster_id, top_n=5)
    combined = top_shelves[:3] + top_words[:3]
    label = ", ".join(combined)
    return label or f"Cluster {cluster_id}"

# %%
for c in range(n_clusters):
    print(c, "→", auto_cluster_label(c))
# Out:
# 0 → to-read, doctor-who, science-fiction, doctor, tv, dw
# 1 → to-read, fiction, currently-reading, fantasy, sci, fi
# 2 → to-read, fiction, currently-reading, fiction, literature, 1001
# 3 → to-read, fiction, currently-reading, children, childhood, childrens
# 4 → to-read, kindle, currently-reading, kindle, free, freebie
# 5 → to-read, romance, harlequin, harlequin, romance, hero
# 6 → to-read, currently-reading, religion, religion, spirituality, philosophy
# 7 → to-read, m-m, mm, mm, romance, gay
# 8 → to-read, historical-fiction, currently-reading, gear, lakes, kathleen
# 9 → to-read, mystery, currently-reading, mystery, cozy, mysteries
# 10 → to-read, paranormal, currently-reading, paranormal, fantasy, series
# 11 → to-read, romance, currently-reading, romance, historical, regency
# 12 → to-read, poetry, currently-reading, poetry, poems, plays
# 13 → to-read, currently-reading, science, science, physics, math
# 14 → to-read, currently-reading, fiction, life, fiction, world
# 15 → to-read, kindle, currently-reading, kindle, mystery, free
# 16 → to-read, childrens, picture-books, children, picture, kids
# 17 → to-read, currently-reading, non-fiction, philosophy, theory, politics
# 18 → to-read, mystery, fiction, mystery, crime, thriller
# 19 → to-read, comics, graphic-novels, comics, graphic, manga
# 20 → to-read, romance, currently-reading, romance, alpha, series
# 21 → to-read, short-stories, currently-reading, short, stories, fiction
# 22 → to-read, sports, currently-reading, sports, hockey, football
# 23 → to-read, currently-reading, christian, christian, fiction, god
# 24 → to-read, currently-reading, science-fiction, apocalyptic, dystopian, post
# 25 → to-read, young-adult, ya, ya, teen, young
# 26 → to-read, non-fiction, currently-reading, memoir, non, biography
# 27 → to-read, currently-reading, romance, romance, series, kindle
# 28 → to-read, currently-reading, animals, animal, animals, nature
# 29 → to-read, history, currently-reading, history, war, non

# %%
cluster_label_map = {c: auto_cluster_label(c) for c in range(n_clusters)}
df["cluster_label"] = df["cluster"].map(cluster_label_map)

df[["title", "cluster", "cluster_label"]].head()
# Out:
#                                                title  cluster  \
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...        1
# 1                               Best Friends Forever        2
# 2            The House of Memory (Pluto's Snitch #2)        9
# 3                        The Bonfire of the Vanities        2
# 4                                             Heaven       23
#
#                                        cluster_label
# 0  to-read, fiction, currently-reading, fantasy, ...
# 1  to-read, fiction, currently-reading, fiction, ...
# 2  to-read, mystery, currently-reading, mystery, ...
# 3  to-read, fiction, currently-reading, fiction, ...
# 4  to-read, currently-reading, christian, christi...
