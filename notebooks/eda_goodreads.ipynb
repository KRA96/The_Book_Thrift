# %%
import pandas as pd
import numpy as np
import re
import ast

from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans



path = "../raw_data/goodreads_books_50k.csv"
df = pd.read_csv(path)

print("shape：", df.shape)
df.head()
# Out:
# shape： (50000, 29)
#          isbn  text_reviews_count      series country_code language_code  \
# 0  0312853122                 1.0          []           US           NaN
# 1  0743509986                 6.0          []           US           NaN
# 2         NaN                 7.0  ['189911']           US           eng
# 3  0743294297              3282.0          []           US           eng
# 4  0850308712                 5.0          []           US           NaN
#
#                                      popular_shelves        asin is_ebook  \
# 0  [{'count': '3', 'name': 'to-read'}, {'count': ...         NaN    False
# 1  [{'count': '2634', 'name': 'to-read'}, {'count...         NaN    False
# 2  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY    False
# 3  [{'count': '7615', 'name': 'to-read'}, {'count...         NaN    False
# 4  [{'count': '32', 'name': 'to-read'}, {'count':...         NaN    False
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.00         NaN  ...               9.0                 NaN
# 1            3.23  B000FC0PBC  ...              10.0            Abridged
# 2            4.03         NaN  ...               NaN   Book Club Edition
# 3            3.49  B002ENBLOK  ...               7.0                 NaN
# 4            3.40         NaN  ...               NaN                 NaN
#
#   publication_year                                                url  \
# 0           1984.0  https://www.goodreads.com/book/show/5333265-w-...
# 1           2001.0  https://www.goodreads.com/book/show/1333909.Go...
# 2           1987.0  https://www.goodreads.com/book/show/7327624-th...
# 3           2009.0  https://www.goodreads.com/book/show/6066819-be...
# 4              NaN  https://www.goodreads.com/book/show/287140.Run...
#
#                                            image_url  book_id  ratings_count  \
# 0  https://images.gr-assets.com/books/1310220028m...  5333265            3.0
# 1  https://s.gr-assets.com/assets/nophoto/book/11...  1333909           10.0
# 2  https://images.gr-assets.com/books/1304100136m...  7327624          140.0
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  6066819        51184.0
# 4  https://images.gr-assets.com/books/1413219371m...   287140           15.0
#
#      work_id                                              title  \
# 0  5400751.0                        W.C. Fields: A Life on Film
# 1  1323437.0                                        Good Harbor
# 2  8948723.0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3  6243154.0                               Best Friends Forever
# 4   278577.0  Runic Astrology: Starcraft and Timekeeping in ...
#
#                                 title_without_series
# 0                        W.C. Fields: A Life on Film
# 1                                        Good Harbor
# 2  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3                               Best Friends Forever
# 4  Runic Astrology: Starcraft and Timekeeping in ...
#
# [5 rows x 29 columns]

# %%
english_codes = ["eng", "en-US", "en-GB", "en-CA","NaN"]
df = df[df["language_code"].isin(english_codes)].copy()

# %%
df = df.dropna(subset=["title", "description"], how="all").reset_index(drop=True)
#drop rows where both title and description are NaN

# %%
df.shape
# Out:
# (18621, 29)

# %%
cols_to_drop = [
    "edition_information",
    "asin",
    "kindle_asin",
    "publication_day",
    "publication_month",
    "format",
    "publisher",
    "isbn"
]

df = df.drop(columns=cols_to_drop, errors="ignore")

# %%
df.shape
# Out:
# (18621, 21)

# %%
for col in ["average_rating", "ratings_count", "text_reviews_count"]:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

df[["average_rating", "ratings_count", "text_reviews_count"]].describe()
# Out:
#        average_rating  ratings_count  text_reviews_count
# count    18621.000000   18621.000000        18621.000000
# mean         3.923501     867.937866           61.632028
# std          0.473281    9684.768052          556.502131
# min          0.000000       0.000000            0.000000
# 25%          3.700000       9.000000            2.000000
# 50%          3.950000      38.000000            7.000000
# 75%          4.190000     174.000000           23.000000
# max          5.000000  575163.000000        38878.000000

# %%
def clean_text(s):
    if not isinstance(s, str):
        return ""
    s = s.lower()
    s = re.sub(r"<.*?>", " ", s)                    # remove HTML tags
    s = s.replace("\n", " ").replace("\r", " ").replace("\t", " ")
    s = re.sub(r"\s+", " ", s).strip()
    return s

# %%
df["title_clean"] = (
    df["title_without_series"]
    .fillna(df["title"])
    .fillna("")
    .astype(str)
    .str.lower()
)

# %%
df["description_clean"] = df["description"].fillna("").astype(str).apply(clean_text)

df[["title_clean", "description_clean"]].head()
# Out:
#                                          title_clean  \
# 0  the unschooled wizard (sun wolf and starhawk, ...
# 1                               best friends forever
# 2            the house of memory (pluto's snitch #2)
# 3                        the bonfire of the vanities
# 4                                             heaven
#
#                                    description_clean
# 0  omnibus book club edition containing the ladie...
# 1  addie downs and valerie adler were eight when ...
# 2
# 3
# 4  what is heaven really going to be like? what w...

# %%
def parse_shelves(s):
    try:
        lst = ast.literal_eval(s)
        return [d.get("name") for d in lst if isinstance(d, dict)]
    except:
        return []

df["shelf_names"] = df["popular_shelves"].apply(parse_shelves)

# %%
NOISE_SHELVES = set([
    "to-read", "currently-reading", "read", "owned", "my-books", "books-i-own",
    "books", "library", "kindle", "kindle-free", "free", "freebie", "default",
    "favorites", "favorite-authors", "have", "i-own", "on-my-shelf", "purchased",
    "unfinished", "did-not-finish"
])

# %%
SYNONYMS = {
    "m-m": "lgbt",
    "m/m": "lgbt",
    "mm": "lgbt",
    "sci-fi": "science-fiction",
    "ya": "young-adult",
    "ya-fiction": "young-adult",
    "childrens": "children",
    "harlequin": "romance",
    "cozy": "cozy-mystery",
    "mysteries": "mystery"
}

# %%
def normalize_shelf(s):

    s = s.lower().strip()
    return SYNONYMS.get(s, s)

def clean_shelves(shelves):

    cleaned = []
    for s in shelves:
        s = s.lower().strip()
        if s in NOISE_SHELVES:
            continue
        cleaned.append(normalize_shelf(s))
    return cleaned

# %%
df["clean_shelves"] = df["shelf_names"].apply(clean_shelves)

# %%
df["shelf_text"] = df["clean_shelves"].apply(
    lambda lst: " ".join(lst) if isinstance(lst, list) else ""
)

df[["shelf_names", "clean_shelves", "shelf_text"]].head()
# Out:
#                                          shelf_names  \
# 0  [to-read, fantasy, fiction, owned, hardcover, ...
# 1  [to-read, chick-lit, currently-reading, fictio...
# 2  [currently-reading, netgalley, kindle, read-20...
# 3  [to-read, fiction, favorites, classics, curren...
# 4  [to-read, currently-reading, theology, christi...
#
#                                        clean_shelves  \
# 0  [fantasy, fiction, hardcover, shelfari-favorit...
# 1  [chick-lit, fiction, jennifer-weiner, chicklit...
# 2  [netgalley, read-2017, read-in-2017, paranorma...
# 3  [fiction, classics, 1001-books, literature, no...
# 4  [theology, christian-life, christian, non-fict...
#
#                                           shelf_text
# 0  fantasy fiction hardcover shelfari-favorites s...
# 1  chick-lit fiction jennifer-weiner chicklit boo...
# 2  netgalley read-2017 read-in-2017 paranormal gh...
# 3  fiction classics 1001-books literature novels ...
# 4  theology christian-life christian non-fiction ...

# %%
def parse_authors(s):
    try:
        lst = ast.literal_eval(s)
        return [d.get("author_id") for d in lst if isinstance(d, dict)]
    except:
        return []

df["author_ids"] = df["authors"].apply(parse_authors)

# %%
def parse_similar(s):
    try:
        return ast.literal_eval(s)
    except:
        return []

df["similar_books_list"] = df["similar_books"].apply(parse_similar)

# %%
# shelves → "fantasy magic young-adult"
df["shelf_text"] = df["shelf_names"].apply(
    lambda lst: " ".join(lst) if isinstance(lst, list) else ""
)

# %%
df["author_text"] = df["author_ids"].apply(
    lambda lst: " ".join("author_" + str(a) for a in lst) if isinstance(lst, list) else ""
)

# %%
# similar_books → "sim_111 sim_222 sim_333"
df["sim_text"] = df["similar_books_list"].apply(
    lambda lst: " ".join("sim_" + str(b) for b in lst) if isinstance(lst, list) else ""
)

# %%
df["combined_text"] = (
    df["title_clean"].fillna("") + " " +
    df["description_clean"].fillna("") + " " +
    df["shelf_text"].fillna("") + " " +
    df["author_text"].fillna("") + " " +
    df["sim_text"].fillna("")
).str.strip()

# %%
vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=30000,
    min_df=5,
    max_df=0.8
)

# %%
tfidf_matrix = vectorizer.fit_transform(df["combined_text"])

tfidf_matrix.shape
# Out:
# (18621, 29526)

# %% [markdown]
# many information is missing in "edition_information", also not helpful, "asin" (Amazon ID, can delete), "kindle_asin" (Kindle Amazin ID), "publication_day", "publication_month", "format", "publisher", "isbn". Could be removed.

# %%
from sklearn.cluster import MiniBatchKMeans

n_clusters = 30

kmeans = MiniBatchKMeans(
    n_clusters=n_clusters,
    random_state=42,
    batch_size=2000
)

cluster_labels = kmeans.fit_predict(tfidf_matrix)

df["cluster"] = cluster_labels

df["cluster"].value_counts().sort_index()
# Out:
# cluster
# 0       45
# 1      907
# 2     1055
# 3      451
# 4      780
# 5      151
# 6      189
# 7      589
# 8        2
# 9      362
# 10     839
# 11     420
# 12     215
# 13      62
# 14    5173
# 15     266
# 16     426
# 17     179
# 18     958
# 19     606
# 20     466
# 21     680
# 22      68
# 23     278
# 24     231
# 25     556
# 26     824
# 27    1277
# 28      84
# 29     482
# Name: count, dtype: int64

# %%
def show_cluster(c, n=15):
    subset = df[df["cluster"] == c]
    return subset[["title", "average_rating", "ratings_count"]].head(n)

# %%
show_cluster(0)
# Out:
#                                                   title  average_rating  \
# 215                               Doctor Who: The Child            3.14
# 1359                          Torchwood: In the Shadows            3.98
# 1474                 Doctor Who: Short Trips - Volume 1            3.59
# 2020                             Torchwood: Exodus Code            3.87
# 2279  Torchwood: Corpse Day (Big Finish Torchwood, #...            3.82
# 2311                The Case of The Disappearing Doctor            3.17
# 2673                            Doctor Who: Scaredy Cat            2.62
# 4126                               Doctor Who: Survival            3.58
# 4572                           Doctor Who: The Forsaken            3.83
# 4684                 The Tunnel At The End Of The Light            2.83
# 5367  Professor Bernice Summerfield and The Greatest...            3.24
# 5647  Doctor Who: The Tenth Doctor Adventures, Volume 1            4.41
# 7215                    Doctor Who: Big Bang Generation            3.19
# 7371                        Doctor Who And The Cybermen            3.57
# 7372                               Doctor Who: Cybermen            3.94
#
#       ratings_count
# 215            29.0
# 1359          211.0
# 1474           68.0
# 2020           96.0
# 2279           38.0
# 2311           12.0
# 2673          144.0
# 4126           89.0
# 4572           36.0
# 4684           20.0
# 5367           34.0
# 5647           51.0
# 7215            4.0
# 7371           28.0
# 7372           68.0

# %%
from collections import Counter

def cluster_top_shelves(cluster_id, top_n=10):
    shelves_series = df[df["cluster"] == cluster_id]["clean_shelves"]
    flat = [s for lst in shelves_series for s in lst]
    c = Counter(flat)
    return c.most_common(top_n)

# %%
cluster_top_shelves(0, top_n=10)
# Out:
# [('science-fiction', 74),
#  ('doctor-who', 41),
#  ('fiction', 32),
#  ('audiobooks', 30),
#  ('dr-who', 30),
#  ('audio', 28),
#  ('audiobook', 24),
#  ('sf', 22),
#  ('fantasy', 21),
#  ('time-travel', 21)]

# %%
import numpy as np

terms = vectorizer.get_feature_names_out()
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

def cluster_keywords(cluster_id, top_n=10):
    return [terms[i] for i in order_centroids[cluster_id, :top_n]]


cluster_keywords(0, top_n=10)
# Out:
# ['doctor',
#  'tv',
#  'dw',
#  'dr',
#  'audio',
#  'big',
#  'audios',
#  'fiction',
#  'tie',
#  'torchwood']

# %%
def auto_cluster_label(cluster_id):
    top_shelves = [s for s, _ in cluster_top_shelves(cluster_id, top_n=5)]
    top_words = cluster_keywords(cluster_id, top_n=5)
    combined = top_shelves[:3] + top_words[:3]
    label = ", ".join(combined)
    return label or f"Cluster {cluster_id}"

# %%
for c in range(n_clusters):
    print(c, "→", auto_cluster_label(c))
# Out:
# 0 → science-fiction, doctor-who, fiction, doctor, tv, dw
# 1 → science-fiction, fiction, fantasy, fantasy, sci, fi
# 2 → fiction, novels, owned-books, fiction, literature, 1001
# 3 → young-adult, children, fiction, children, childhood, childrens
# 4 → romance, ebook, freebies, kindle, free, freebie
# 5 → romance, contemporary-romance, contemporary, harlequin, romance, hero
# 6 → religion, non-fiction, nonfiction, religion, spirituality, philosophy
# 7 → lgbt, romance, m-m-romance, mm, romance, gay
# 8 → historical-fiction, fiction, native-american, gear, lakes, kathleen
# 9 → mystery, cozy-mystery, series, mystery, cozy, mysteries
# 10 → paranormal, romance, fantasy, paranormal, fantasy, series
# 11 → romance, historical, historical-romance, romance, historical, regency
# 12 → poetry, fiction, poems, poetry, poems, plays
# 13 → science, non-fiction, nonfiction, science, physics, math
# 14 → fiction, fantasy, science-fiction, life, fiction, world
# 15 → mystery, fiction, ebook, kindle, mystery, free
# 16 → children, picture-books, children-s, children, picture, kids
# 17 → non-fiction, nonfiction, philosophy, philosophy, theory, politics
# 18 → mystery, fiction, thriller, mystery, crime, thriller
# 19 → comics, graphic-novels, graphic-novel, comics, graphic, manga
# 20 → romance, contemporary-romance, contemporary, romance, alpha, series
# 21 → short-stories, fiction, science-fiction, short, stories, fiction
# 22 → sports, romance, contemporary, sports, hockey, football
# 23 → christian, christian-fiction, fiction, christian, fiction, god
# 24 → science-fiction, young-adult, dystopian, apocalyptic, dystopian, post
# 25 → young-adult, fiction, romance, ya, teen, young
# 26 → non-fiction, nonfiction, biography, memoir, non, biography
# 27 → romance, contemporary, contemporary-romance, romance, series, kindle
# 28 → animals, non-fiction, nonfiction, animal, animals, nature
# 29 → history, non-fiction, nonfiction, history, war, non

# %%
cluster_label_map = {c: auto_cluster_label(c) for c in range(n_clusters)}
df["cluster_label"] = df["cluster"].map(cluster_label_map)

df[["title", "cluster", "cluster_label"]].head()
# Out:
#                                                title  cluster  \
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...        1
# 1                               Best Friends Forever        2
# 2            The House of Memory (Pluto's Snitch #2)        9
# 3                        The Bonfire of the Vanities        2
# 4                                             Heaven       23
#
#                                        cluster_label
# 0  science-fiction, fiction, fantasy, fantasy, sc...
# 1  fiction, novels, owned-books, fiction, literat...
# 2  mystery, cozy-mystery, series, mystery, cozy, ...
# 3  fiction, novels, owned-books, fiction, literat...
# 4  christian, christian-fiction, fiction, christi...

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def get_similar_books_by_index(book_idx, df, tfidf_matrix, top_n=5):
    book_vec = tfidf_matrix[book_idx]
    sim_scores = cosine_similarity(book_vec, tfidf_matrix).flatten()
    sorted_idx = np.argsort(sim_scores)[::-1]
    sorted_idx = [i for i in sorted_idx if i != book_idx]
    top_indices = sorted_idx[:top_n]

    cols = ["title"]
    for extra in ["average_rating", "ratings_count", "cluster"]:
        if extra in df.columns:
            cols.append(extra)
    result = df.loc[top_indices, cols].copy()
    result["similarity"] = sim_scores[top_indices]
    print(f"📚 index = {book_idx} | book name：《{df.loc[book_idx, 'title']}》 the most similar 5 books：\n")
    return result

# %%
get_similar_books_by_index(0, df, tfidf_matrix, top_n=5)
# Out:
# 📚 index = 0 | book name：《The Unschooled Wizard (Sun Wolf and Starhawk, #1-2)》 the most similar 5 books：
#                                                    title  average_rating  \
# 8771             Another Fine Myth (Myth Adventures, #1)            4.03
# 11316                                             Tigana            4.12
# 15682  The Charnel Prince (Kingdoms of Thorn and Bone...            3.81
# 4176              Ship of Destiny (Liveship Traders, #3)            4.21
# 13142                     The King of Elfland's Daughter            3.83
#
#        ratings_count  cluster  similarity
# 8771            15.0        1    0.495011
# 11316          180.0        1    0.480931
# 15682         5278.0        1    0.471000
# 4176           576.0        1    0.428692
# 13142           11.0        1    0.422645

# %%
def recommend_similar_books(title, df, tfidf_matrix, top_n=5, same_cluster=False):
    matches = df[df["title"].str.lower() == title.lower()]
    if matches.empty:
        print(f"No book found with title '{title}'")
    book_idx = matches.index[0]
    if same_cluster and "cluster" in df.columns:
        c = df.loc[book_idx, "cluster"]
        candidate_idx = df.index[df["cluster"] == c].to_list()
    else:
        candidate_idx = df.index.to_list()

    sub_matrix = tfidf_matrix[candidate_idx]
    sim_scores = cosine_similarity(tfidf_matrix[book_idx], sub_matrix).flatten()
    sorted_pos = np.argsort(sim_scores)[::-1]
    try:
        self_pos = candidate_idx.index(book_idx)
    except ValueError:
        self_pos = None

    top_indices = []
    for p in sorted_pos:
        if self_pos is not None and p == self_pos:
            continue
        top_indices.append(candidate_idx[p])
        if len(top_indices) >= top_n:
            break

    cols = ["title"]
    for extra in ["average_rating", "ratings_count", "cluster"]:
        if extra in df.columns:
            cols.append(extra)
    result = df.loc[top_indices, cols].copy()
    result["similarity"] = sim_scores[[candidate_idx.index(i) for i in top_indices]]
    print(f"📚 book name：《{df.loc[book_idx, 'title']}》 the most similar {top_n} books：\n")
    return result

# %%
recommend_similar_books(
    "Best Friends Forever",   # 换成你 df 里真实存在的书名
    df,
    tfidf_matrix,
    top_n=5,
    same_cluster=False
)
# Out:
# 📚 book name：《Best Friends Forever》 the most similar 5 books：
#                          title  average_rating  ratings_count  cluster  \
# 4169             Then Came You            3.69          113.0        2
# 8065              In Her Shoes            3.78          709.0        2
# 6387       Heart of the Matter            3.73         2338.0        2
# 7327  Love the One You're With            3.70          538.0        2
# 2387          Beginner's Greek            3.19         2271.0        2
#
#       similarity
# 4169    0.377812
# 8065    0.312206
# 6387    0.306253
# 7327    0.297680
# 2387    0.276925

# %%
recommend_similar_books(
    "Best Friends Forever",
    df,
    tfidf_matrix,
    top_n=5,
    same_cluster=True
)
# Out:
# 📚 book name：《Best Friends Forever》 the most similar 5 books：
#                          title  average_rating  ratings_count  cluster  \
# 4169             Then Came You            3.69          113.0        2
# 8065              In Her Shoes            3.78          709.0        2
# 6387       Heart of the Matter            3.73         2338.0        2
# 7327  Love the One You're With            3.70          538.0        2
# 2387          Beginner's Greek            3.19         2271.0        2
#
#       similarity
# 4169    0.377812
# 8065    0.312206
# 6387    0.306253
# 7327    0.297680
# 2387    0.276925
